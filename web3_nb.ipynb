# %%
from web3 import Web3
import erc20

# %%
infura_url = "https://mainnet.infura.io/v3/7f9398e6cc404b89adf97d5e686efb5b"

# %%
web3 = Web3(Web3.HTTPProvider(infura_url))
print(web3.isConnected())
print(web3.eth.blockNumber)
# Out:
# True
# 13451447

# %%
web3.eth.get_block('latest')
# Out:
# AttributeDict({'baseFeePerGas': 58047717026,
#  'difficulty': 9770213877862974,
#  'extraData': HexBytes('0x486976656f6e2073672d6865617679'),
#  'gasLimit': 30035226,
#  'gasUsed': 7861637,
#  'hash': HexBytes('0x2dd9087bdf43751771f6aa0a5427bad9a43105f27c200f744fa6719f7d88b20d'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0x1aD91ee08f21bE3dE0BA2ba6918E714dA6B45836',
#  'mixHash': HexBytes('0xd455aa0650966cdbf3aabd083fad8182fc86876180d9ed4f37a9d7ab5a5d85ac'),
#  'nonce': HexBytes('0x62cd00b17ced0db3'),
#  'number': 13451492,
#  'parentHash': HexBytes('0x6e6c4484c17bcde2e3d0106f3bd62ed4b5012b7ab7abf54bffce39fe1f0a67de'),
#  'receiptsRoot': HexBytes('0xa8a34f647b5b785b1f1a80a443f807b9ec0308046f9573103c72020d53dd4382'),
#  'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#  'size': 25739,
#  'stateRoot': HexBytes('0xf26e5f0c98c015f38d3a987ea182a7cec57618ebad8b942ccd1e8b2c1e2ec960'),
#  'timestamp': 1634690724,
# ...

# %%
web3.eth.get_transaction_by_block('0x2dd9087bdf43751771f6aa0a5427bad9a43105f27c200f744fa6719f7d88b20d',0)
# Out:
# AttributeDict({'blockHash': HexBytes('0x2dd9087bdf43751771f6aa0a5427bad9a43105f27c200f744fa6719f7d88b20d'),
#  'blockNumber': 13451492,
#  'from': '0x666666A0200c2B78EddD1ef279488C6A714f010d',
#  'gas': 310000,
#  'gasPrice': 122000000000,
#  'hash': HexBytes('0x6657b6beaa0fc2233116be09eae55b5752d06204fb9fe6cfdfaa1cf6c870c28c'),
#  'input': '...',
#  'nonce': 11743,
#  'r': HexBytes('0xe124267cd95e74b2e61be63aa92e1e4e9db92466ede79ab8051811d6b15659fd'),
#  's': HexBytes('0x1787ebbab1cca09d32944a59b2fa4aa44b4c8e3a60891c072381bfbe995776ba'),
#  'to': '0x7a250d5630B4cF539739dF2C5dAcb4c659F2488D',
#  'transactionIndex': 0,
#  'type': '0x0',
#  'v': 37,
#  'value': 0})

# %%
# "wallet" address hash
account = Web3.toChecksumAddress("0xaaca6c17b822a4b5074d4ca4dabd99a8bd04f41b")
balance = web3.eth.getBalance(account)
print("Ether balance: {0}".format(web3.fromWei(balance, "ether")))
print(web3.eth.get_transaction_count(account))
# Out:
# Ether balance: 0.05922428476759038
# 2

# %%
txn_01 = "0x8983685a27ba0416bb740c4c368b81b9c2c634a8558c98e2b90ffd16c2a6bced"
web3.eth.get_transaction(txn_01)
# Out:
# AttributeDict({'accessList': [],
#  'blockHash': HexBytes('0xceba347e9853898c87d57d5b8b92be146cbe8c9a626ad7eee0cd4f85c8809586'),
#  'blockNumber': 13407081,
#  'chainId': '0x1',
#  'from': '0xb5d85CBf7cB3EE0D56b3bB207D5Fc4B82f43F511',
#  'gas': 21000,
#  'gasPrice': 58637847565,
#  'hash': HexBytes('0x8983685a27ba0416bb740c4c368b81b9c2c634a8558c98e2b90ffd16c2a6bced'),
#  'input': '0x',
#  'maxFeePerGas': 124000000000,
#  'maxPriorityFeePerGas': 2000000000,
#  'nonce': 2916048,
#  'r': HexBytes('0x65d9f2a07c4c762e3d199d0da9a68742701e401bd5f4a616edf2eaaa4ccc0359'),
#  's': HexBytes('0x6616565f7ce83636394e9a54677036fc05fdfa0ca7b6aced504f9e5b60fa0fd2'),
#  'to': '0xAACA6C17b822a4b5074d4cA4DabD99a8Bd04F41B',
#  'transactionIndex': 327,
#  'type': '0x2',
#  'v': 1,
#  'value': 90000000000000000})

# %%
txn_02 = '0x840c0380b1c98511bab963a4416bc0a7630e4e0a5f5bd4b04f0cd2c99ee03fcf'
web3.eth.get_transaction(txn_02)
# Out:
# AttributeDict({'accessList': [],
#  'blockHash': HexBytes('0x9989985302dbaeaff88315f34d7d74ef3587a57bb54540f22d1a78ef7fc851f2'),
#  'blockNumber': 13410303,
#  'chainId': '0x1',
#  'from': '0xAACA6C17b822a4b5074d4cA4DabD99a8Bd04F41B',
#  'gas': 254245,
#  'gasPrice': 61999727220,
#  'hash': HexBytes('0x840c0380b1c98511bab963a4416bc0a7630e4e0a5f5bd4b04f0cd2c99ee03fcf'),
#  'input': '...',
#  'maxFeePerGas': 95550452223,
#  'maxPriorityFeePerGas': 1500000000,
#  'nonce': 1,
#  'r': HexBytes('0x9695d249351802680cab74eab22334cfb7254a6631654b99133dc0dc6af10852'),
#  's': HexBytes('0x35af123cf3296b1d9487dd3009bad1129db93f879385fd0490e34103c5f694c8'),
#  'to': '0x7Be8076f4EA4A4AD08075C2508e481d6C946D12b',
#  'transactionIndex': 167,
#  'type': '0x2',
#  'v': 1,
#  'value': 0})
